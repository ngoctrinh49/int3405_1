# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision.transforms as transforms
from torchvision import datasets
# %matplotlib inline

# %% [markdown]
# #Mô hình hoá dữ liệu

# %%
#convert dữ liệu vê dạng torch tensor để pytorch xử lý và tính toán
transform = transforms.ToTensor()

#tập dữ liệu traning 
train_data = datasets.MNIST(root='data', train=True, download=True, transform=transform)

#data loader
#batch_size: số lượng mẫu dữ liệu / batch khi load 
#num_worker=0: dữ liệu được load trong tiến trình chính
train_loader = torch.utils.data.DataLoader(train_data, batch_size=64, num_workers=0)

# %%
#batch ảnh train 
detaiter = iter(train_loader)
images, labels = detaiter.next()
images = images.numpy()

#lấy một ảnh từ batch 
img = np.squeeze(images[0])

#plot 
fig = plt.figure(figsize=(3, 3))
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')

# %% [markdown]
# #Định nghĩa mô hình
# GAN bao gồm hai mạng đối nghịch: discriminator và generator
# ##Discriminator
# Mạng D là bộ phân loại tuyến tính. Cần ít nhất một lớp ẩn với một thuộc tính chính (key attribute) để xấp xỉ universal function
#
#
# > Các lớp ẩn có hàm kích hoạt Leaky Relu áp dụng cho output:
#
# ![picture](https://drive.google.com/uc?export=view&id=1mqisUJmhbHupH4kX2VUbo1HVRc6MOsK2)
#
# ### Leaky Relu
# Hàm leaky Relu tương tự như hàm ReLU nhưng nó thay thế phần âm của ReLU bằng hàm tuyến tính với hệ số góc nhỏ cố định.
# ![picture](https://drive.google.com/uc?export=view&id=1Czk8QuQ1lVQXikaqVY6-TVk6M-6jeftY)
#
# ### Sigmoid Output
# Giá trị ouput của D là 0 - 1 để nhận biết ảnh giả và ảnh thật
#
#
# > BCEWithLogisLoss kết hợp hàm kích hoạt sigmoid và binary cross entropy loss trong một hàm

# %%
import torch.nn as nn
import torch.nn.functional as F

class Discriminator(nn.Module):
  def __init__(self, input_size, hidden_dim, output_size):
    super(Discriminator, self).__init__()     #chu y 

    #định nghĩa hidden linear layers
    self.fc1 = nn.Linear(input_size, hidden_dim * 4)

    print("self.fc1: ", self.fc1)

    self.fc2 = nn.Linear(hidden_dim * 4, hidden_dim * 2)
    self.fc3 = nn.Linear(hidden_dim * 2, hidden_dim)
    self.fc4 = nn.Linear(hidden_dim, output_size)

    #dropout để bỏ một số nút mạng để tránh over-fitting 
    self.dropout = nn.Dropout(p=0.3)

  def forward(self, x):
    #sau khi sử dụng các lớp tích chập để trích xuất được các đặc trưng của ảnh thì 
    #vẫn qua 1 lớp flatten để trải phẳng ma trận 2 chiều thành vector 1 chiều
    x = x.view(-1, 28*28)

    #tất cả hidden layers
    x = F.leaky_relu(self.fc1(x), 0.2)
    x = self.dropout(x)

    x = F.leaky_relu(self.fc2(x), 0.2)
    x = self.dropout(x)

    x = F.leaky_relu(self.fc3(x), 0.2)
    x = self.dropout(x)

    #final layer
    out = self.fc4(x)

    return out

# %% [markdown]
# Trong đó fc1, fc2, fc3 là các fully connected layers. Các feature được truyền qua bắt đầu từ fc1 đến fc4.
# Hàm forward dùng leaky_relu để phi tuyến tính hoá output đầu ra

# %% [markdown]
# ##Generator
# Mạng G gần tương tự như D nhưng có thêm hàm kích hoạt tanh ở layer output
#
# Hàm tanh nhận đầu vào là số thực và đầu ra là khoảng (-1; 1)
# ![picture](https://drive.google.com/uc?export=view&id=1ivCurjNi2xlMlobZBH47iMZCDJyICMc_)

# %%
class Generator(nn.Module):
  def __init__(self, input_size, hidden_dim, output_size):
    super(Generator, self).__init__()

    self.fc1 = nn.Linear(input_size, hidden_dim)
    self.fc2 = nn.Linear(hidden_dim, hidden_dim * 2)
    self.fc3 = nn.Linear(hidden_dim * 2, hidden_dim * 4)
    self. fc4 = nn.Linear(hidden_dim * 4, output_size)

    self.dropout = nn.Dropout(0.3)

  def forward(self, x):
    x = F.leaky_relu(self.fc1(x), 0.2)
    x = self.dropout(x)

    x = F.leaky_relu(self.fc2(x), 0.2)
    x = self.dropout(x)

    x = F.leaky_relu(self.fc3(x), 0.2)
    x = self.dropout(x)

    #hàm tạnh cho final layer
    out = F.tanh(self.fc4(x))

    return out

# %% [markdown]
# ##Model hyperparameters
# Các hyperparameter dùng để train GAN:

# %%
# Discriminator hyperparams

# Kích thước ảnh input discriminator (28*28)
input_size = 784
# Kích thước ảnh output discriminator (real or fake)
d_output_size = 1
# Kích thước last hidden layer discriminator
d_hidden_size = 32

# Generator hyperparams

# Kích thước latent vector của generator
z_size = 100
# Kích thước discriminator output (generated image)
g_output_size = 784
# Kích thước first hidden layer của generator
g_hidden_size = 32

# %% [markdown]
# #Khởi tạo mô hình hoàn chỉnh

# %%
# khởi tạo discriminator and generator
D = Discriminator(input_size, d_hidden_size, d_output_size)
G = Generator(z_size, g_hidden_size, g_output_size)

print(D)
print()
print(G)
# Out:
# self.fc1:  Linear(in_features=784, out_features=128, bias=True)
# Discriminator(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=1, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )
#
# Generator(
#   (fc1): Linear(in_features=100, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=784, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %% [markdown]
# #Hàm loss của Discriminator và Generator

# %%
def real_loss(D_out, smooth=False):
    batch_size = D_out.size(0)
    # label smoothing
    if smooth:
        # real labels = 0.9
        labels = torch.ones(batch_size) * 0.9
    else: #not smooth
        labels = torch.ones(batch_size) # real labels = 1
        
    # numerically stable loss
    criterion = nn.BCEWithLogitsLoss()
    # Tính hàm loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# #Thuật toán tối ưu
# Cập nhật tham số D và G dùng thuật toán Adam

# %%
import torch.optim as optim

lr = 0.002

d_optimizer = optim.Adam(D.parameters(), lr)
g_optimizer = optim.Adam(G.parameters(), lr)

# %% [markdown]
# #Training
# ##Discriminator training
#
# 1.   Tính hàm loss của D với ảnh thật (training)
# 2.   G sinh ảnh giả
# 3. Tính hàm loss của D với ảnh giả (ảnh do G sinh ra)
# 4. Cộng hai hàm loss với nhau
# 5. Thực hiện lan truyền ngược và áo dụng thuật toán tối ưu để update D's weights
#
# ##Generator training
#
#
# 1.   G sinh ảnh giả
# 2.   Tính hàm loss của D với ảnh giả
# 3. Thực hiện lan truyền ngược và áp dụng thuật toán tối ưu để update G's weights

# %%
import pickle as pkl

numberOfEpochs = 200

samples = []
losses = []           #giá trị loss

sample_size = 16
fixed_z = np.random.uniform(-1, 1, size = (sample_size, z_size))   #(16, 100)
fixed_z = torch.from_numpy(fixed_z).float()

D.train()
G.train()

i = 0

for epoch in range(numberOfEpochs):
  for batch_i, (real_images, _) in enumerate(train_loader):
    i += 1
    batch_size = real_images.size(0)
    real_images = real_images * 2 - 1 #rescale input [0, 1) -> [-1, 1)
    
    #Train D

    d_optimizer.zero_grad()

    #1. train với ảnh thực
    D_real = D(real_images)
    d_real_loss = real_loss(D_real, smooth = True)    #giá trị hàm loss với ảnh thật 

    #2. Train với ảnh giả
    with torch.no_grad():
      z = np.random.uniform(-1, 1, size = (batch_size, z_size))
      z = torch.from_numpy(z).float()
      fake_images = G(z)

    #tính hàm loss của D với ảnh giả
    D_fake = D(fake_images)
    d_fake_loss = fake_loss(D_fake)

    #cộng hai hàm loss và lan truyền ngược
    d_loss = d_real_loss + d_fake_loss
    d_loss.backward()
    d_optimizer.step()

    #TRAIN G

    g_optimizer.zero_grad()

    #1. train với ảnh giả

    #G sinh ảnh giả
    z = np.random.uniform(-1, 1, size = (batch_size, z_size))
    z = torch.from_numpy(z).float()
    fake_images = G(z)

    #tính hàm loss G trong tập ảnh giả dùng flipped labels
    D_fake = D(fake_images)
    g_loss = real_loss(D_fake)

    #lan truyền ngược
    g_loss.backward()
    g_optimizer.step()

    #in giá trị loss
    if batch_i % 400 == 0:
      print('Epoch[{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(epoch + 1, numberOfEpochs, d_loss.item(), g_loss.item()))

  #sau mỗi epoch
  #append D loss và G loss 
  losses.append((d_loss.item(), g_loss.item()))
  G.eval()
  sample_z = G(fixed_z)
  samples.append(sample_z)
  G.train()   #train G

print("số vòng lặp train của D: ", i)

with open('train_samples.pkl', 'wb') as f:
  pkl.dump(samples, f)
# Out:
# Epoch[    1/  200] | d_loss: 1.4109 | g_loss: 0.7146
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch[    1/  200] | d_loss: 0.8105 | g_loss: 1.8333
# Epoch[    1/  200] | d_loss: 1.5322 | g_loss: 0.6430
# Epoch[    2/  200] | d_loss: 1.4163 | g_loss: 0.7363
# Epoch[    2/  200] | d_loss: 1.5638 | g_loss: 0.8475
# Epoch[    2/  200] | d_loss: 1.1023 | g_loss: 1.4165
# Epoch[    3/  200] | d_loss: 1.3315 | g_loss: 0.8808
# Epoch[    3/  200] | d_loss: 1.1212 | g_loss: 1.1819
# Epoch[    3/  200] | d_loss: 0.9815 | g_loss: 1.5107
# Epoch[    4/  200] | d_loss: 1.1764 | g_loss: 0.7935
# Epoch[    4/  200] | d_loss: 1.2640 | g_loss: 1.2198
# Epoch[    4/  200] | d_loss: 1.1462 | g_loss: 1.2849
# Epoch[    5/  200] | d_loss: 1.1411 | g_loss: 2.1081
# Epoch[    5/  200] | d_loss: 0.9701 | g_loss: 1.4269
# Epoch[    5/  200] | d_loss: 1.0438 | g_loss: 1.8981
# Epoch[    6/  200] | d_loss: 1.4873 | g_loss: 0.7074
# Epoch[    6/  200] | d_loss: 0.9338 | g_loss: 2.3184
# Epoch[    6/  200] | d_loss: 1.0447 | g_loss: 2.0777
# Epoch[    7/  200] | d_loss: 1.0957 | g_loss: 1.3548
# Epoch[    7/  200] | d_loss: 1.0418 | g_loss: 1.3503
# Epoch[    7/  200] | d_loss: 1.0947 | g_loss: 1.0579
# Epoch[    8/  200] | d_loss: 1.0712 | g_loss: 2.0370
# Epoch[    8/  200] | d_loss: 1.0342 | g_loss: 1.6740
# Epoch[    8/  200] | d_loss: 1.0599 | g_loss: 1.3205
# Epoch[    9/  200] | d_loss: 1.1773 | g_loss: 1.5881
# Epoch[    9/  200] | d_loss: 1.0843 | g_loss: 2.1315
# Epoch[    9/  200] | d_loss: 1.3453 | g_loss: 0.9182
# Epoch[   10/  200] | d_loss: 1.2438 | g_loss: 1.1462
# Epoch[   10/  200] | d_loss: 1.3493 | g_loss: 0.8566
# Epoch[   10/  200] | d_loss: 1.1605 | g_loss: 1.1318
# Epoch[   11/  200] | d_loss: 1.3187 | g_loss: 0.9305
# Epoch[   11/  200] | d_loss: 1.3265 | g_loss: 1.2137
# Epoch[   11/  200] | d_loss: 1.2478 | g_loss: 0.9405
# Epoch[   12/  200] | d_loss: 1.2046 | g_loss: 0.9675
# Epoch[   12/  200] | d_loss: 1.2234 | g_loss: 1.1001
# Epoch[   12/  200] | d_loss: 1.2458 | g_loss: 1.2822
# Epoch[   13/  200] | d_loss: 1.2511 | g_loss: 1.1196
# Epoch[   13/  200] | d_loss: 1.3045 | g_loss: 0.9011
# Epoch[   13/  200] | d_loss: 1.3006 | g_loss: 0.9268
# Epoch[   14/  200] | d_loss: 1.3865 | g_loss: 1.0054
# Epoch[   14/  200] | d_loss: 1.3347 | g_loss: 0.9568
# Epoch[   14/  200] | d_loss: 1.3736 | g_loss: 0.9458
# Epoch[   15/  200] | d_loss: 1.3242 | g_loss: 1.0487
# Epoch[   15/  200] | d_loss: 1.2786 | g_loss: 1.0222
# Epoch[   15/  200] | d_loss: 1.2506 | g_loss: 1.0332
# Epoch[   16/  200] | d_loss: 1.1871 | g_loss: 1.1746
# Epoch[   16/  200] | d_loss: 1.3468 | g_loss: 1.0131
# Epoch[   16/  200] | d_loss: 1.4244 | g_loss: 0.9600
# Epoch[   17/  200] | d_loss: 1.3191 | g_loss: 0.9840
# Epoch[   17/  200] | d_loss: 1.2007 | g_loss: 1.2000
# Epoch[   17/  200] | d_loss: 1.2413 | g_loss: 0.8320
# Epoch[   18/  200] | d_loss: 1.4334 | g_loss: 0.7853
# Epoch[   18/  200] | d_loss: 1.1796 | g_loss: 1.3049
# Epoch[   18/  200] | d_loss: 1.2307 | g_loss: 0.9529
# Epoch[   19/  200] | d_loss: 1.2018 | g_loss: 1.3635
# Epoch[   19/  200] | d_loss: 1.2881 | g_loss: 1.0431
# Epoch[   19/  200] | d_loss: 1.2978 | g_loss: 0.9291
# Epoch[   20/  200] | d_loss: 1.2792 | g_loss: 0.8375
# Epoch[   20/  200] | d_loss: 1.2930 | g_loss: 0.9490
# Epoch[   20/  200] | d_loss: 1.2807 | g_loss: 0.9981
# Epoch[   21/  200] | d_loss: 1.2418 | g_loss: 1.1346
# Epoch[   21/  200] | d_loss: 1.2092 | g_loss: 0.9857
# Epoch[   21/  200] | d_loss: 1.3826 | g_loss: 0.8976
# Epoch[   22/  200] | d_loss: 1.2885 | g_loss: 0.8773
# Epoch[   22/  200] | d_loss: 1.2386 | g_loss: 1.0356
# Epoch[   22/  200] | d_loss: 1.2603 | g_loss: 0.9164
# Epoch[   23/  200] | d_loss: 1.3037 | g_loss: 0.9455
# Epoch[   23/  200] | d_loss: 1.2800 | g_loss: 1.0475
# Epoch[   23/  200] | d_loss: 1.3529 | g_loss: 0.9090
# Epoch[   24/  200] | d_loss: 1.3361 | g_loss: 0.8683
# Epoch[   24/  200] | d_loss: 1.2954 | g_loss: 1.0788
# Epoch[   24/  200] | d_loss: 1.3222 | g_loss: 0.9347
# Epoch[   25/  200] | d_loss: 1.3301 | g_loss: 1.2716
# Epoch[   25/  200] | d_loss: 1.2864 | g_loss: 0.8825
# Epoch[   25/  200] | d_loss: 1.2750 | g_loss: 0.8831
# Epoch[   26/  200] | d_loss: 1.3465 | g_loss: 1.1860
# Epoch[   26/  200] | d_loss: 1.3015 | g_loss: 0.9514
# Epoch[   26/  200] | d_loss: 1.3678 | g_loss: 0.9412
# Epoch[   27/  200] | d_loss: 1.3285 | g_loss: 0.7492
# Epoch[   27/  200] | d_loss: 1.2077 | g_loss: 1.1253
# Epoch[   27/  200] | d_loss: 1.3243 | g_loss: 0.9722
# Epoch[   28/  200] | d_loss: 1.2934 | g_loss: 1.1344
# Epoch[   28/  200] | d_loss: 1.2369 | g_loss: 0.9856
# Epoch[   28/  200] | d_loss: 1.2823 | g_loss: 1.4362
# Epoch[   29/  200] | d_loss: 1.2153 | g_loss: 1.1462
# Epoch[   29/  200] | d_loss: 1.2935 | g_loss: 0.8859
# Epoch[   29/  200] | d_loss: 1.3503 | g_loss: 0.8665
# Epoch[   30/  200] | d_loss: 1.3878 | g_loss: 1.3992
# Epoch[   30/  200] | d_loss: 1.2530 | g_loss: 0.9199
# Epoch[   30/  200] | d_loss: 1.4258 | g_loss: 1.2283
# Epoch[   31/  200] | d_loss: 1.2762 | g_loss: 1.0818
# Epoch[   31/  200] | d_loss: 1.2936 | g_loss: 0.8826
# Epoch[   31/  200] | d_loss: 1.3411 | g_loss: 1.1190
# Epoch[   32/  200] | d_loss: 1.2609 | g_loss: 1.0980
# Epoch[   32/  200] | d_loss: 1.2383 | g_loss: 1.1633
# Epoch[   32/  200] | d_loss: 1.3558 | g_loss: 1.0164
# Epoch[   33/  200] | d_loss: 1.3302 | g_loss: 1.2007
# Epoch[   33/  200] | d_loss: 1.3154 | g_loss: 0.8684
# Epoch[   33/  200] | d_loss: 1.3142 | g_loss: 0.9204
# Epoch[   34/  200] | d_loss: 1.3127 | g_loss: 1.0749
# Epoch[   34/  200] | d_loss: 1.2481 | g_loss: 0.9701
# Epoch[   34/  200] | d_loss: 1.3939 | g_loss: 0.9724
# Epoch[   35/  200] | d_loss: 1.2962 | g_loss: 1.0349
# Epoch[   35/  200] | d_loss: 1.3622 | g_loss: 0.7886
# Epoch[   35/  200] | d_loss: 1.4166 | g_loss: 0.9555
# Epoch[   36/  200] | d_loss: 1.3256 | g_loss: 1.1385
# Epoch[   36/  200] | d_loss: 1.2431 | g_loss: 1.1850
# Epoch[   36/  200] | d_loss: 1.2927 | g_loss: 0.9266
# Epoch[   37/  200] | d_loss: 1.3495 | g_loss: 0.7724
# Epoch[   37/  200] | d_loss: 1.3664 | g_loss: 0.8955
# Epoch[   37/  200] | d_loss: 1.3321 | g_loss: 0.8433
# Epoch[   38/  200] | d_loss: 1.3871 | g_loss: 0.8253
# Epoch[   38/  200] | d_loss: 1.3027 | g_loss: 0.9474
# Epoch[   38/  200] | d_loss: 1.2962 | g_loss: 1.2452
# Epoch[   39/  200] | d_loss: 1.2453 | g_loss: 1.2191
# Epoch[   39/  200] | d_loss: 1.3232 | g_loss: 0.8571
# Epoch[   39/  200] | d_loss: 1.4126 | g_loss: 0.9519
# Epoch[   40/  200] | d_loss: 1.3020 | g_loss: 0.9047
# Epoch[   40/  200] | d_loss: 1.3712 | g_loss: 0.8991
# Epoch[   40/  200] | d_loss: 1.2657 | g_loss: 1.2289
# Epoch[   41/  200] | d_loss: 1.2726 | g_loss: 0.8119
# Epoch[   41/  200] | d_loss: 1.2562 | g_loss: 0.8859
# Epoch[   41/  200] | d_loss: 1.2560 | g_loss: 1.0186
# Epoch[   42/  200] | d_loss: 1.2271 | g_loss: 0.9230
# Epoch[   42/  200] | d_loss: 1.3118 | g_loss: 1.0228
# Epoch[   42/  200] | d_loss: 1.3312 | g_loss: 0.9369
# Epoch[   43/  200] | d_loss: 1.2882 | g_loss: 1.2811
# Epoch[   43/  200] | d_loss: 1.2350 | g_loss: 1.0670
# Epoch[   43/  200] | d_loss: 1.4564 | g_loss: 0.8550
# Epoch[   44/  200] | d_loss: 1.5130 | g_loss: 0.9905
# Epoch[   44/  200] | d_loss: 1.4617 | g_loss: 1.2009
# Epoch[   44/  200] | d_loss: 1.4084 | g_loss: 0.9423
# Epoch[   45/  200] | d_loss: 1.3538 | g_loss: 1.1106
# Epoch[   45/  200] | d_loss: 1.2595 | g_loss: 0.8626
# Epoch[   45/  200] | d_loss: 1.3299 | g_loss: 0.9501
# Epoch[   46/  200] | d_loss: 1.3507 | g_loss: 0.9779
# Epoch[   46/  200] | d_loss: 1.3019 | g_loss: 0.8452
# Epoch[   46/  200] | d_loss: 1.3256 | g_loss: 0.9820
# Epoch[   47/  200] | d_loss: 1.3050 | g_loss: 0.8737
# Epoch[   47/  200] | d_loss: 1.3605 | g_loss: 0.8945
# Epoch[   47/  200] | d_loss: 1.3605 | g_loss: 0.9565
# Epoch[   48/  200] | d_loss: 1.3390 | g_loss: 1.0691
# Epoch[   48/  200] | d_loss: 1.3289 | g_loss: 1.0617
# Epoch[   48/  200] | d_loss: 1.3933 | g_loss: 1.0188
# Epoch[   49/  200] | d_loss: 1.3412 | g_loss: 0.8964
# Epoch[   49/  200] | d_loss: 1.3997 | g_loss: 0.9676
# Epoch[   49/  200] | d_loss: 1.3497 | g_loss: 1.1497
# Epoch[   50/  200] | d_loss: 1.2901 | g_loss: 0.9002
# Epoch[   50/  200] | d_loss: 1.3274 | g_loss: 0.9139
# Epoch[   50/  200] | d_loss: 1.3876 | g_loss: 0.9825
# Epoch[   51/  200] | d_loss: 1.3771 | g_loss: 0.8157
# Epoch[   51/  200] | d_loss: 1.2128 | g_loss: 0.9515
# Epoch[   51/  200] | d_loss: 1.3909 | g_loss: 0.7807
# Epoch[   52/  200] | d_loss: 1.2676 | g_loss: 0.9002
# Epoch[   52/  200] | d_loss: 1.2761 | g_loss: 1.2256
# Epoch[   52/  200] | d_loss: 1.3080 | g_loss: 0.8136
# Epoch[   53/  200] | d_loss: 1.3606 | g_loss: 0.8971
# Epoch[   53/  200] | d_loss: 1.2271 | g_loss: 0.9674
# Epoch[   53/  200] | d_loss: 1.3351 | g_loss: 0.9330
# Epoch[   54/  200] | d_loss: 1.1698 | g_loss: 1.2949
# Epoch[   54/  200] | d_loss: 1.2762 | g_loss: 0.9749
# Epoch[   54/  200] | d_loss: 1.4392 | g_loss: 1.0748
# Epoch[   55/  200] | d_loss: 1.3954 | g_loss: 1.2494
# Epoch[   55/  200] | d_loss: 1.3185 | g_loss: 1.0730
# Epoch[   55/  200] | d_loss: 1.3836 | g_loss: 1.1258
# Epoch[   56/  200] | d_loss: 1.4095 | g_loss: 0.8920
# Epoch[   56/  200] | d_loss: 1.2921 | g_loss: 0.9955
# Epoch[   56/  200] | d_loss: 1.5064 | g_loss: 0.9022
# Epoch[   57/  200] | d_loss: 1.2263 | g_loss: 1.3181
# Epoch[   57/  200] | d_loss: 1.2581 | g_loss: 0.7691
# Epoch[   57/  200] | d_loss: 1.3080 | g_loss: 0.9068
# Epoch[   58/  200] | d_loss: 1.3771 | g_loss: 1.0348
# Epoch[   58/  200] | d_loss: 1.2852 | g_loss: 1.1324
# Epoch[   58/  200] | d_loss: 1.3351 | g_loss: 1.0015
# Epoch[   59/  200] | d_loss: 1.2931 | g_loss: 0.9299
# Epoch[   59/  200] | d_loss: 1.2501 | g_loss: 1.2962
# Epoch[   59/  200] | d_loss: 1.3928 | g_loss: 0.8253
# Epoch[   60/  200] | d_loss: 1.3835 | g_loss: 0.9283
# Epoch[   60/  200] | d_loss: 1.3191 | g_loss: 0.9587
# Epoch[   60/  200] | d_loss: 1.4751 | g_loss: 1.0692
# Epoch[   61/  200] | d_loss: 1.2836 | g_loss: 0.9240
# Epoch[   61/  200] | d_loss: 1.3042 | g_loss: 0.9562
# Epoch[   61/  200] | d_loss: 1.3441 | g_loss: 1.1494
# Epoch[   62/  200] | d_loss: 1.2623 | g_loss: 0.8040
# Epoch[   62/  200] | d_loss: 1.3375 | g_loss: 0.9672
# Epoch[   62/  200] | d_loss: 1.3198 | g_loss: 0.9801
# Epoch[   63/  200] | d_loss: 1.1929 | g_loss: 1.8772
# Epoch[   63/  200] | d_loss: 1.1692 | g_loss: 0.9297
# Epoch[   63/  200] | d_loss: 1.3648 | g_loss: 1.0250
# Epoch[   64/  200] | d_loss: 1.1862 | g_loss: 1.4256
# Epoch[   64/  200] | d_loss: 1.3052 | g_loss: 1.1178
# Epoch[   64/  200] | d_loss: 1.4879 | g_loss: 1.0121
# Epoch[   65/  200] | d_loss: 1.2483 | g_loss: 1.1921
# Epoch[   65/  200] | d_loss: 1.3046 | g_loss: 0.9627
# Epoch[   65/  200] | d_loss: 1.3750 | g_loss: 1.0158
# Epoch[   66/  200] | d_loss: 1.3699 | g_loss: 0.9366
# Epoch[   66/  200] | d_loss: 1.3142 | g_loss: 0.8460
# Epoch[   66/  200] | d_loss: 1.3845 | g_loss: 0.8516
# Epoch[   67/  200] | d_loss: 1.3062 | g_loss: 0.9598
# Epoch[   67/  200] | d_loss: 1.2999 | g_loss: 1.0147
# Epoch[   67/  200] | d_loss: 1.3927 | g_loss: 0.9262
# Epoch[   68/  200] | d_loss: 1.1628 | g_loss: 1.1216
# Epoch[   68/  200] | d_loss: 1.3734 | g_loss: 0.8934
# Epoch[   68/  200] | d_loss: 1.3244 | g_loss: 0.8913
# Epoch[   69/  200] | d_loss: 1.2917 | g_loss: 0.9906
# Epoch[   69/  200] | d_loss: 1.2346 | g_loss: 1.2676
# Epoch[   69/  200] | d_loss: 1.3241 | g_loss: 0.9286
# Epoch[   70/  200] | d_loss: 1.4187 | g_loss: 0.8749
# Epoch[   70/  200] | d_loss: 1.2500 | g_loss: 1.3078
# Epoch[   70/  200] | d_loss: 1.4331 | g_loss: 0.8916
# Epoch[   71/  200] | d_loss: 1.2519 | g_loss: 1.6034
# Epoch[   71/  200] | d_loss: 1.4424 | g_loss: 1.1229
# Epoch[   71/  200] | d_loss: 1.3981 | g_loss: 0.9231
# Epoch[   72/  200] | d_loss: 1.3140 | g_loss: 0.9172
# Epoch[   72/  200] | d_loss: 1.2031 | g_loss: 0.9751
# Epoch[   72/  200] | d_loss: 1.4939 | g_loss: 0.9777
# Epoch[   73/  200] | d_loss: 1.3806 | g_loss: 0.8814
# Epoch[   73/  200] | d_loss: 1.3295 | g_loss: 0.9747
# Epoch[   73/  200] | d_loss: 1.4006 | g_loss: 0.9625
# Epoch[   74/  200] | d_loss: 1.2790 | g_loss: 0.8438
# Epoch[   74/  200] | d_loss: 1.3117 | g_loss: 0.9041
# Epoch[   74/  200] | d_loss: 1.3449 | g_loss: 1.4752
# Epoch[   75/  200] | d_loss: 1.3021 | g_loss: 1.0634
# Epoch[   75/  200] | d_loss: 1.3074 | g_loss: 0.9002
# Epoch[   75/  200] | d_loss: 1.3514 | g_loss: 0.9441
# Epoch[   76/  200] | d_loss: 1.4054 | g_loss: 0.7684
# Epoch[   76/  200] | d_loss: 1.3734 | g_loss: 0.9536
# Epoch[   76/  200] | d_loss: 1.3184 | g_loss: 1.1100
# Epoch[   77/  200] | d_loss: 1.3275 | g_loss: 0.9093
# Epoch[   77/  200] | d_loss: 1.2581 | g_loss: 0.9024
# Epoch[   77/  200] | d_loss: 1.4518 | g_loss: 0.8716
# Epoch[   78/  200] | d_loss: 1.4220 | g_loss: 0.9435
# Epoch[   78/  200] | d_loss: 1.3560 | g_loss: 0.8731
# Epoch[   78/  200] | d_loss: 1.2823 | g_loss: 0.9950
# Epoch[   79/  200] | d_loss: 1.3015 | g_loss: 0.8949
# Epoch[   79/  200] | d_loss: 1.2824 | g_loss: 1.0444
# Epoch[   79/  200] | d_loss: 1.3764 | g_loss: 0.9882
# Epoch[   80/  200] | d_loss: 1.2543 | g_loss: 0.9393
# Epoch[   80/  200] | d_loss: 1.3024 | g_loss: 0.9882
# Epoch[   80/  200] | d_loss: 1.3053 | g_loss: 0.9929
# Epoch[   81/  200] | d_loss: 1.1458 | g_loss: 1.7085
# Epoch[   81/  200] | d_loss: 1.2491 | g_loss: 1.4058
# Epoch[   81/  200] | d_loss: 1.4227 | g_loss: 0.9929
# Epoch[   82/  200] | d_loss: 1.3506 | g_loss: 1.0317
# Epoch[   82/  200] | d_loss: 1.3069 | g_loss: 0.9547
# Epoch[   82/  200] | d_loss: 1.3136 | g_loss: 1.0425
# Epoch[   83/  200] | d_loss: 1.2541 | g_loss: 0.9060
# Epoch[   83/  200] | d_loss: 1.2386 | g_loss: 0.8694
# Epoch[   83/  200] | d_loss: 1.3989 | g_loss: 0.8670
# Epoch[   84/  200] | d_loss: 1.4416 | g_loss: 1.0326
# Epoch[   84/  200] | d_loss: 1.2762 | g_loss: 0.8642
# Epoch[   84/  200] | d_loss: 1.2470 | g_loss: 1.0050
# Epoch[   85/  200] | d_loss: 1.1766 | g_loss: 1.1932
# Epoch[   85/  200] | d_loss: 1.3177 | g_loss: 1.2447
# Epoch[   85/  200] | d_loss: 1.4098 | g_loss: 1.0592
# Epoch[   86/  200] | d_loss: 1.2653 | g_loss: 1.0619
# Epoch[   86/  200] | d_loss: 1.2470 | g_loss: 1.1630
# Epoch[   86/  200] | d_loss: 1.3140 | g_loss: 1.1667
# Epoch[   87/  200] | d_loss: 1.2979 | g_loss: 0.9373
# Epoch[   87/  200] | d_loss: 1.3203 | g_loss: 0.8615
# Epoch[   87/  200] | d_loss: 1.2846 | g_loss: 1.2622
# Epoch[   88/  200] | d_loss: 1.2814 | g_loss: 0.9159
# Epoch[   88/  200] | d_loss: 1.2992 | g_loss: 0.9849
# Epoch[   88/  200] | d_loss: 1.3002 | g_loss: 1.1782
# Epoch[   89/  200] | d_loss: 1.3236 | g_loss: 1.0107
# Epoch[   89/  200] | d_loss: 1.3012 | g_loss: 1.2307
# Epoch[   89/  200] | d_loss: 1.3231 | g_loss: 0.9738
# Epoch[   90/  200] | d_loss: 1.2747 | g_loss: 1.0941
# Epoch[   90/  200] | d_loss: 1.2592 | g_loss: 0.9955
# Epoch[   90/  200] | d_loss: 1.2884 | g_loss: 1.1136
# Epoch[   91/  200] | d_loss: 1.2082 | g_loss: 0.9107
# Epoch[   91/  200] | d_loss: 1.2485 | g_loss: 1.0361
# Epoch[   91/  200] | d_loss: 1.4368 | g_loss: 1.0316
# Epoch[   92/  200] | d_loss: 1.2872 | g_loss: 1.0765
# Epoch[   92/  200] | d_loss: 1.2480 | g_loss: 0.9565
# Epoch[   92/  200] | d_loss: 1.2610 | g_loss: 1.1786
# Epoch[   93/  200] | d_loss: 1.3009 | g_loss: 0.8424
# Epoch[   93/  200] | d_loss: 1.2338 | g_loss: 1.4878
# Epoch[   93/  200] | d_loss: 1.3386 | g_loss: 0.9974
# Epoch[   94/  200] | d_loss: 1.2910 | g_loss: 1.0205
# Epoch[   94/  200] | d_loss: 1.1979 | g_loss: 0.8861
# Epoch[   94/  200] | d_loss: 1.3276 | g_loss: 0.9391
# Epoch[   95/  200] | d_loss: 1.3118 | g_loss: 0.9356
# Epoch[   95/  200] | d_loss: 1.3310 | g_loss: 0.9843
# Epoch[   95/  200] | d_loss: 1.4344 | g_loss: 0.9883
# Epoch[   96/  200] | d_loss: 1.2328 | g_loss: 0.9791
# Epoch[   96/  200] | d_loss: 1.2510 | g_loss: 1.1383
# Epoch[   96/  200] | d_loss: 1.3554 | g_loss: 0.8337
# Epoch[   97/  200] | d_loss: 1.3318 | g_loss: 1.0454
# Epoch[   97/  200] | d_loss: 1.3210 | g_loss: 0.9383
# Epoch[   97/  200] | d_loss: 1.3623 | g_loss: 0.9185
# Epoch[   98/  200] | d_loss: 1.3006 | g_loss: 1.1654
# Epoch[   98/  200] | d_loss: 1.2842 | g_loss: 0.9353
# Epoch[   98/  200] | d_loss: 1.4258 | g_loss: 0.9559
# Epoch[   99/  200] | d_loss: 1.1933 | g_loss: 1.0411
# Epoch[   99/  200] | d_loss: 1.3055 | g_loss: 0.9805
# Epoch[   99/  200] | d_loss: 1.3252 | g_loss: 0.9421
# Epoch[  100/  200] | d_loss: 1.2020 | g_loss: 1.3300
# Epoch[  100/  200] | d_loss: 1.2794 | g_loss: 1.1974
# Epoch[  100/  200] | d_loss: 1.3695 | g_loss: 1.0702
# Epoch[  101/  200] | d_loss: 1.2452 | g_loss: 1.0765
# Epoch[  101/  200] | d_loss: 1.3296 | g_loss: 1.0249
# Epoch[  101/  200] | d_loss: 1.3984 | g_loss: 0.9194
# Epoch[  102/  200] | d_loss: 1.2811 | g_loss: 1.0607
# Epoch[  102/  200] | d_loss: 1.2753 | g_loss: 0.9477
# Epoch[  102/  200] | d_loss: 1.3768 | g_loss: 1.3274
# Epoch[  103/  200] | d_loss: 1.2967 | g_loss: 1.1278
# Epoch[  103/  200] | d_loss: 1.1971 | g_loss: 1.1671
# Epoch[  103/  200] | d_loss: 1.3012 | g_loss: 0.9869
# Epoch[  104/  200] | d_loss: 1.3109 | g_loss: 1.0135
# Epoch[  104/  200] | d_loss: 1.3312 | g_loss: 1.1665
# Epoch[  104/  200] | d_loss: 1.3335 | g_loss: 1.1048
# Epoch[  105/  200] | d_loss: 1.2490 | g_loss: 1.0878
# Epoch[  105/  200] | d_loss: 1.3422 | g_loss: 1.0226
# Epoch[  105/  200] | d_loss: 1.2767 | g_loss: 0.9346
# Epoch[  106/  200] | d_loss: 1.2475 | g_loss: 1.0748
# Epoch[  106/  200] | d_loss: 1.3262 | g_loss: 0.8574
# Epoch[  106/  200] | d_loss: 1.3826 | g_loss: 0.9934
# Epoch[  107/  200] | d_loss: 1.2134 | g_loss: 1.1401
# Epoch[  107/  200] | d_loss: 1.2642 | g_loss: 1.0780
# Epoch[  107/  200] | d_loss: 1.3991 | g_loss: 1.0876
# Epoch[  108/  200] | d_loss: 1.2644 | g_loss: 1.0668
# Epoch[  108/  200] | d_loss: 1.2405 | g_loss: 0.8941
# Epoch[  108/  200] | d_loss: 1.4909 | g_loss: 1.0140
# Epoch[  109/  200] | d_loss: 1.2145 | g_loss: 1.0085
# Epoch[  109/  200] | d_loss: 1.2271 | g_loss: 1.1197
# Epoch[  109/  200] | d_loss: 1.3381 | g_loss: 1.2712
# Epoch[  110/  200] | d_loss: 1.2513 | g_loss: 1.2770
# Epoch[  110/  200] | d_loss: 1.2171 | g_loss: 1.1061
# Epoch[  110/  200] | d_loss: 1.4982 | g_loss: 1.3424
# Epoch[  111/  200] | d_loss: 1.3053 | g_loss: 0.8915
# Epoch[  111/  200] | d_loss: 1.2991 | g_loss: 0.9038
# Epoch[  111/  200] | d_loss: 1.4660 | g_loss: 1.1622
# Epoch[  112/  200] | d_loss: 1.2741 | g_loss: 1.3079
# Epoch[  112/  200] | d_loss: 1.3492 | g_loss: 0.8667
# Epoch[  112/  200] | d_loss: 1.3045 | g_loss: 0.9275
# Epoch[  113/  200] | d_loss: 1.2831 | g_loss: 0.9135
# Epoch[  113/  200] | d_loss: 1.2116 | g_loss: 0.9576
# Epoch[  113/  200] | d_loss: 1.2831 | g_loss: 1.1581
# Epoch[  114/  200] | d_loss: 1.3114 | g_loss: 0.9615
# Epoch[  114/  200] | d_loss: 1.2810 | g_loss: 1.0498
# Epoch[  114/  200] | d_loss: 1.2923 | g_loss: 1.2435
# Epoch[  115/  200] | d_loss: 1.4073 | g_loss: 0.9955
# Epoch[  115/  200] | d_loss: 1.2789 | g_loss: 1.0953
# Epoch[  115/  200] | d_loss: 1.2690 | g_loss: 1.0599
# Epoch[  116/  200] | d_loss: 1.2012 | g_loss: 1.7047
# Epoch[  116/  200] | d_loss: 1.2466 | g_loss: 1.1958
# Epoch[  116/  200] | d_loss: 1.4118 | g_loss: 0.9723
# Epoch[  117/  200] | d_loss: 1.2617 | g_loss: 1.0482
# Epoch[  117/  200] | d_loss: 1.2683 | g_loss: 1.0804
# Epoch[  117/  200] | d_loss: 1.3388 | g_loss: 0.8795
# Epoch[  118/  200] | d_loss: 1.3704 | g_loss: 1.1053
# Epoch[  118/  200] | d_loss: 1.2121 | g_loss: 0.9650
# Epoch[  118/  200] | d_loss: 1.4097 | g_loss: 0.9513
# Epoch[  119/  200] | d_loss: 1.2008 | g_loss: 0.9335
# Epoch[  119/  200] | d_loss: 1.2406 | g_loss: 1.0574
# Epoch[  119/  200] | d_loss: 1.3566 | g_loss: 1.1010
# Epoch[  120/  200] | d_loss: 1.2017 | g_loss: 1.3261
# Epoch[  120/  200] | d_loss: 1.2513 | g_loss: 0.9972
# Epoch[  120/  200] | d_loss: 1.4211 | g_loss: 1.2888
# Epoch[  121/  200] | d_loss: 1.2850 | g_loss: 1.1607
# Epoch[  121/  200] | d_loss: 1.3560 | g_loss: 1.2923
# Epoch[  121/  200] | d_loss: 1.3762 | g_loss: 0.9816
# Epoch[  122/  200] | d_loss: 1.1894 | g_loss: 1.4632
# Epoch[  122/  200] | d_loss: 1.2264 | g_loss: 0.9837
# Epoch[  122/  200] | d_loss: 1.3795 | g_loss: 1.0808
# Epoch[  123/  200] | d_loss: 1.2780 | g_loss: 0.9667
# Epoch[  123/  200] | d_loss: 1.2404 | g_loss: 1.2252
# Epoch[  123/  200] | d_loss: 1.4454 | g_loss: 0.9733
# Epoch[  124/  200] | d_loss: 1.3838 | g_loss: 0.9508
# Epoch[  124/  200] | d_loss: 1.3281 | g_loss: 0.9369
# Epoch[  124/  200] | d_loss: 1.2982 | g_loss: 0.9136
# Epoch[  125/  200] | d_loss: 1.3909 | g_loss: 1.3230
# Epoch[  125/  200] | d_loss: 1.3258 | g_loss: 1.0429
# Epoch[  125/  200] | d_loss: 1.3125 | g_loss: 0.8137
# Epoch[  126/  200] | d_loss: 1.3558 | g_loss: 1.0134
# Epoch[  126/  200] | d_loss: 1.3244 | g_loss: 0.9299
# Epoch[  126/  200] | d_loss: 1.3675 | g_loss: 0.9124
# Epoch[  127/  200] | d_loss: 1.3169 | g_loss: 1.1276
# Epoch[  127/  200] | d_loss: 1.2971 | g_loss: 0.9995
# Epoch[  127/  200] | d_loss: 1.3145 | g_loss: 1.2577
# Epoch[  128/  200] | d_loss: 1.3237 | g_loss: 1.3729
# Epoch[  128/  200] | d_loss: 1.2357 | g_loss: 1.0675
# Epoch[  128/  200] | d_loss: 1.3436 | g_loss: 1.1008
# Epoch[  129/  200] | d_loss: 1.2806 | g_loss: 1.1185
# Epoch[  129/  200] | d_loss: 1.2251 | g_loss: 0.8340
# Epoch[  129/  200] | d_loss: 1.3229 | g_loss: 0.8180
# Epoch[  130/  200] | d_loss: 1.4407 | g_loss: 1.1906
# Epoch[  130/  200] | d_loss: 1.2447 | g_loss: 1.0293
# Epoch[  130/  200] | d_loss: 1.3053 | g_loss: 1.0668
# Epoch[  131/  200] | d_loss: 1.1875 | g_loss: 1.1098
# Epoch[  131/  200] | d_loss: 1.1870 | g_loss: 0.9375
# Epoch[  131/  200] | d_loss: 1.3528 | g_loss: 1.1087
# Epoch[  132/  200] | d_loss: 1.2436 | g_loss: 1.0838
# Epoch[  132/  200] | d_loss: 1.3118 | g_loss: 1.1702
# Epoch[  132/  200] | d_loss: 1.3783 | g_loss: 0.9101
# Epoch[  133/  200] | d_loss: 1.2118 | g_loss: 1.1641
# Epoch[  133/  200] | d_loss: 1.2987 | g_loss: 0.9234
# Epoch[  133/  200] | d_loss: 1.3847 | g_loss: 0.9523
# Epoch[  134/  200] | d_loss: 1.3623 | g_loss: 1.0014
# Epoch[  134/  200] | d_loss: 1.2253 | g_loss: 1.0306
# Epoch[  134/  200] | d_loss: 1.3644 | g_loss: 0.9598
# Epoch[  135/  200] | d_loss: 1.2039 | g_loss: 0.9598
# Epoch[  135/  200] | d_loss: 1.1810 | g_loss: 1.4663
# Epoch[  135/  200] | d_loss: 1.3722 | g_loss: 1.1256
# Epoch[  136/  200] | d_loss: 1.2563 | g_loss: 1.0235
# Epoch[  136/  200] | d_loss: 1.2857 | g_loss: 0.9663
# Epoch[  136/  200] | d_loss: 1.3586 | g_loss: 0.9478
# Epoch[  137/  200] | d_loss: 1.3422 | g_loss: 0.7421
# Epoch[  137/  200] | d_loss: 1.1688 | g_loss: 1.2486
# Epoch[  137/  200] | d_loss: 1.3806 | g_loss: 1.0085
# Epoch[  138/  200] | d_loss: 1.2050 | g_loss: 0.9288
# Epoch[  138/  200] | d_loss: 1.2844 | g_loss: 1.0364
# Epoch[  138/  200] | d_loss: 1.3148 | g_loss: 1.3114
# Epoch[  139/  200] | d_loss: 1.3548 | g_loss: 1.4074
# Epoch[  139/  200] | d_loss: 1.2248 | g_loss: 1.1090
# Epoch[  139/  200] | d_loss: 1.2965 | g_loss: 0.9778
# Epoch[  140/  200] | d_loss: 1.1887 | g_loss: 1.2444
# Epoch[  140/  200] | d_loss: 1.1930 | g_loss: 1.1988
# Epoch[  140/  200] | d_loss: 1.3243 | g_loss: 1.1801
# Epoch[  141/  200] | d_loss: 1.2589 | g_loss: 0.9974
# Epoch[  141/  200] | d_loss: 1.3327 | g_loss: 1.1731
# Epoch[  141/  200] | d_loss: 1.4238 | g_loss: 0.9868
# Epoch[  142/  200] | d_loss: 1.2733 | g_loss: 1.1986
# Epoch[  142/  200] | d_loss: 1.2865 | g_loss: 0.9373
# Epoch[  142/  200] | d_loss: 1.4339 | g_loss: 1.2011
# Epoch[  143/  200] | d_loss: 1.1948 | g_loss: 1.2990
# Epoch[  143/  200] | d_loss: 1.3190 | g_loss: 0.9593
# Epoch[  143/  200] | d_loss: 1.3809 | g_loss: 0.8846
# Epoch[  144/  200] | d_loss: 1.2907 | g_loss: 1.3634
# Epoch[  144/  200] | d_loss: 1.1253 | g_loss: 1.0860
# Epoch[  144/  200] | d_loss: 1.4058 | g_loss: 0.8941
# Epoch[  145/  200] | d_loss: 1.1935 | g_loss: 1.4091
# Epoch[  145/  200] | d_loss: 1.1798 | g_loss: 1.1597
# Epoch[  145/  200] | d_loss: 1.4101 | g_loss: 0.9583
# Epoch[  146/  200] | d_loss: 1.1971 | g_loss: 0.9875
# Epoch[  146/  200] | d_loss: 1.2883 | g_loss: 0.9278
# Epoch[  146/  200] | d_loss: 1.3317 | g_loss: 1.1248
# Epoch[  147/  200] | d_loss: 1.3412 | g_loss: 0.9917
# Epoch[  147/  200] | d_loss: 1.2703 | g_loss: 1.2202
# Epoch[  147/  200] | d_loss: 1.3532 | g_loss: 0.9541
# Epoch[  148/  200] | d_loss: 1.2852 | g_loss: 0.9466
# Epoch[  148/  200] | d_loss: 1.1565 | g_loss: 1.3933
# Epoch[  148/  200] | d_loss: 1.4495 | g_loss: 1.0807
# Epoch[  149/  200] | d_loss: 1.3482 | g_loss: 1.3150
# Epoch[  149/  200] | d_loss: 1.3040 | g_loss: 1.2930
# Epoch[  149/  200] | d_loss: 1.2972 | g_loss: 0.9207
# Epoch[  150/  200] | d_loss: 1.3075 | g_loss: 1.3583
# Epoch[  150/  200] | d_loss: 1.2063 | g_loss: 1.0914
# Epoch[  150/  200] | d_loss: 1.3778 | g_loss: 0.9923
# Epoch[  151/  200] | d_loss: 1.2646 | g_loss: 1.1082
# Epoch[  151/  200] | d_loss: 1.3184 | g_loss: 1.0148
# Epoch[  151/  200] | d_loss: 1.4096 | g_loss: 1.1044
# Epoch[  152/  200] | d_loss: 1.3150 | g_loss: 1.0528
# Epoch[  152/  200] | d_loss: 1.3268 | g_loss: 1.2927
# Epoch[  152/  200] | d_loss: 1.3759 | g_loss: 0.9950
# Epoch[  153/  200] | d_loss: 1.2090 | g_loss: 1.3316
# Epoch[  153/  200] | d_loss: 1.1931 | g_loss: 0.9858
# Epoch[  153/  200] | d_loss: 1.3160 | g_loss: 0.9931
# Epoch[  154/  200] | d_loss: 1.2782 | g_loss: 1.1271
# Epoch[  154/  200] | d_loss: 1.3461 | g_loss: 1.0021
# Epoch[  154/  200] | d_loss: 1.3585 | g_loss: 1.0243
# Epoch[  155/  200] | d_loss: 1.2856 | g_loss: 1.0659
# Epoch[  155/  200] | d_loss: 1.2438 | g_loss: 1.2325
# Epoch[  155/  200] | d_loss: 1.4959 | g_loss: 1.0408
# Epoch[  156/  200] | d_loss: 1.3309 | g_loss: 1.1648
# Epoch[  156/  200] | d_loss: 1.2446 | g_loss: 0.8297
# Epoch[  156/  200] | d_loss: 1.3109 | g_loss: 1.0220
# Epoch[  157/  200] | d_loss: 1.2425 | g_loss: 0.9508
# Epoch[  157/  200] | d_loss: 1.3268 | g_loss: 0.9506
# Epoch[  157/  200] | d_loss: 1.4503 | g_loss: 1.0803
# Epoch[  158/  200] | d_loss: 1.2080 | g_loss: 1.2502
# Epoch[  158/  200] | d_loss: 1.2020 | g_loss: 0.9496
# Epoch[  158/  200] | d_loss: 1.4680 | g_loss: 0.9626
# Epoch[  159/  200] | d_loss: 1.2946 | g_loss: 1.1307
# Epoch[  159/  200] | d_loss: 1.2788 | g_loss: 0.8837
# Epoch[  159/  200] | d_loss: 1.3903 | g_loss: 0.9028
# Epoch[  160/  200] | d_loss: 1.2403 | g_loss: 1.4862
# Epoch[  160/  200] | d_loss: 1.2280 | g_loss: 1.0040
# Epoch[  160/  200] | d_loss: 1.3510 | g_loss: 0.9708
# Epoch[  161/  200] | d_loss: 1.2056 | g_loss: 1.3106
# Epoch[  161/  200] | d_loss: 1.2700 | g_loss: 1.0754
# Epoch[  161/  200] | d_loss: 1.2500 | g_loss: 1.1933
# Epoch[  162/  200] | d_loss: 1.2589 | g_loss: 0.9779
# Epoch[  162/  200] | d_loss: 1.1922 | g_loss: 1.2264
# Epoch[  162/  200] | d_loss: 1.2534 | g_loss: 1.1687
# Epoch[  163/  200] | d_loss: 1.3171 | g_loss: 1.0367
# Epoch[  163/  200] | d_loss: 1.2687 | g_loss: 0.9290
# Epoch[  163/  200] | d_loss: 1.3794 | g_loss: 1.1114
# Epoch[  164/  200] | d_loss: 1.4276 | g_loss: 1.3763
# Epoch[  164/  200] | d_loss: 1.3062 | g_loss: 1.2177
# Epoch[  164/  200] | d_loss: 1.3651 | g_loss: 1.0477
# Epoch[  165/  200] | d_loss: 1.3029 | g_loss: 1.2089
# Epoch[  165/  200] | d_loss: 1.1979 | g_loss: 0.9768
# Epoch[  165/  200] | d_loss: 1.2599 | g_loss: 1.2265
# Epoch[  166/  200] | d_loss: 1.3265 | g_loss: 0.9932
# Epoch[  166/  200] | d_loss: 1.2814 | g_loss: 1.1224
# Epoch[  166/  200] | d_loss: 1.2843 | g_loss: 1.2396
# Epoch[  167/  200] | d_loss: 1.1649 | g_loss: 0.9829
# Epoch[  167/  200] | d_loss: 1.2306 | g_loss: 0.9198
# Epoch[  167/  200] | d_loss: 1.3682 | g_loss: 1.1279
# Epoch[  168/  200] | d_loss: 1.2658 | g_loss: 0.9577
# Epoch[  168/  200] | d_loss: 1.2838 | g_loss: 1.0307
# Epoch[  168/  200] | d_loss: 1.4450 | g_loss: 1.0219
# Epoch[  169/  200] | d_loss: 1.2666 | g_loss: 1.5227
# Epoch[  169/  200] | d_loss: 1.2545 | g_loss: 1.3592
# Epoch[  169/  200] | d_loss: 1.3274 | g_loss: 1.1641
# Epoch[  170/  200] | d_loss: 1.2153 | g_loss: 1.2213
# Epoch[  170/  200] | d_loss: 1.2621 | g_loss: 0.9151
# Epoch[  170/  200] | d_loss: 1.3006 | g_loss: 1.2644
# Epoch[  171/  200] | d_loss: 1.3317 | g_loss: 1.2203
# Epoch[  171/  200] | d_loss: 1.2318 | g_loss: 0.9673
# Epoch[  171/  200] | d_loss: 1.4567 | g_loss: 0.9111
# Epoch[  172/  200] | d_loss: 1.2244 | g_loss: 0.9774
# Epoch[  172/  200] | d_loss: 1.1671 | g_loss: 1.1237
# Epoch[  172/  200] | d_loss: 1.5108 | g_loss: 1.0769
# Epoch[  173/  200] | d_loss: 1.4179 | g_loss: 1.0498
# Epoch[  173/  200] | d_loss: 1.2774 | g_loss: 1.0924
# Epoch[  173/  200] | d_loss: 1.4875 | g_loss: 1.0607
# Epoch[  174/  200] | d_loss: 1.1349 | g_loss: 1.6897
# Epoch[  174/  200] | d_loss: 1.1900 | g_loss: 1.2317
# Epoch[  174/  200] | d_loss: 1.3942 | g_loss: 1.3530
# Epoch[  175/  200] | d_loss: 1.4822 | g_loss: 0.9028
# Epoch[  175/  200] | d_loss: 1.2442 | g_loss: 1.0800
# Epoch[  175/  200] | d_loss: 1.3400 | g_loss: 0.9933
# Epoch[  176/  200] | d_loss: 1.3104 | g_loss: 0.9163
# Epoch[  176/  200] | d_loss: 1.2707 | g_loss: 1.2699
# Epoch[  176/  200] | d_loss: 1.2387 | g_loss: 0.9383
# Epoch[  177/  200] | d_loss: 1.2151 | g_loss: 1.0573
# Epoch[  177/  200] | d_loss: 1.1771 | g_loss: 1.0052
# Epoch[  177/  200] | d_loss: 1.5546 | g_loss: 1.2602
# Epoch[  178/  200] | d_loss: 1.1759 | g_loss: 1.4240
# Epoch[  178/  200] | d_loss: 1.2311 | g_loss: 1.0654
# Epoch[  178/  200] | d_loss: 1.3639 | g_loss: 1.0205
# Epoch[  179/  200] | d_loss: 1.4953 | g_loss: 1.1492
# Epoch[  179/  200] | d_loss: 1.2512 | g_loss: 1.0960
# Epoch[  179/  200] | d_loss: 1.2117 | g_loss: 1.0983
# Epoch[  180/  200] | d_loss: 1.1816 | g_loss: 1.3126
# Epoch[  180/  200] | d_loss: 1.1947 | g_loss: 1.0111
# Epoch[  180/  200] | d_loss: 1.3474 | g_loss: 1.3149
# Epoch[  181/  200] | d_loss: 1.2257 | g_loss: 1.2503
# Epoch[  181/  200] | d_loss: 1.1568 | g_loss: 1.7519
# Epoch[  181/  200] | d_loss: 1.2934 | g_loss: 1.2222
# Epoch[  182/  200] | d_loss: 1.2161 | g_loss: 1.0593
# Epoch[  182/  200] | d_loss: 1.0994 | g_loss: 1.2984
# Epoch[  182/  200] | d_loss: 1.2940 | g_loss: 1.4674
# Epoch[  183/  200] | d_loss: 1.3432 | g_loss: 1.2766
# Epoch[  183/  200] | d_loss: 1.2328 | g_loss: 1.1542
# Epoch[  183/  200] | d_loss: 1.3245 | g_loss: 0.9926
# Epoch[  184/  200] | d_loss: 1.2837 | g_loss: 1.1469
# Epoch[  184/  200] | d_loss: 1.2334 | g_loss: 1.1961
# Epoch[  184/  200] | d_loss: 1.3770 | g_loss: 1.1074
# Epoch[  185/  200] | d_loss: 1.2086 | g_loss: 0.9447
# Epoch[  185/  200] | d_loss: 1.2252 | g_loss: 0.9564
# Epoch[  185/  200] | d_loss: 1.2752 | g_loss: 1.0184
# Epoch[  186/  200] | d_loss: 1.4100 | g_loss: 1.4981
# Epoch[  186/  200] | d_loss: 1.3600 | g_loss: 1.1431
# Epoch[  186/  200] | d_loss: 1.2117 | g_loss: 0.9808
# Epoch[  187/  200] | d_loss: 1.2820 | g_loss: 1.0608
# Epoch[  187/  200] | d_loss: 1.3490 | g_loss: 1.0115
# Epoch[  187/  200] | d_loss: 1.4180 | g_loss: 1.1012
# Epoch[  188/  200] | d_loss: 1.3184 | g_loss: 0.9654
# Epoch[  188/  200] | d_loss: 1.2684 | g_loss: 0.8752
# Epoch[  188/  200] | d_loss: 1.4268 | g_loss: 1.0515
# Epoch[  189/  200] | d_loss: 1.1929 | g_loss: 0.9597
# Epoch[  189/  200] | d_loss: 1.2545 | g_loss: 1.0305
# Epoch[  189/  200] | d_loss: 1.3062 | g_loss: 1.0069
# Epoch[  190/  200] | d_loss: 1.3488 | g_loss: 0.9977
# Epoch[  190/  200] | d_loss: 1.2751 | g_loss: 1.2224
# Epoch[  190/  200] | d_loss: 1.3877 | g_loss: 0.9557
# Epoch[  191/  200] | d_loss: 1.1520 | g_loss: 1.0424
# Epoch[  191/  200] | d_loss: 1.2488 | g_loss: 1.0258
# Epoch[  191/  200] | d_loss: 1.3334 | g_loss: 1.2800
# Epoch[  192/  200] | d_loss: 1.2410 | g_loss: 1.1097
# Epoch[  192/  200] | d_loss: 1.0434 | g_loss: 1.3181
# Epoch[  192/  200] | d_loss: 1.4633 | g_loss: 0.8935
# Epoch[  193/  200] | d_loss: 1.2560 | g_loss: 1.5037
# Epoch[  193/  200] | d_loss: 1.2375 | g_loss: 0.8971
# Epoch[  193/  200] | d_loss: 1.3317 | g_loss: 1.0161
# Epoch[  194/  200] | d_loss: 1.3016 | g_loss: 1.0953
# Epoch[  194/  200] | d_loss: 1.2802 | g_loss: 1.1666
# Epoch[  194/  200] | d_loss: 1.4247 | g_loss: 1.2398
# Epoch[  195/  200] | d_loss: 1.2765 | g_loss: 1.2348
# Epoch[  195/  200] | d_loss: 1.1893 | g_loss: 1.0415
# Epoch[  195/  200] | d_loss: 1.4163 | g_loss: 1.1165
# Epoch[  196/  200] | d_loss: 1.1815 | g_loss: 1.2228
# Epoch[  196/  200] | d_loss: 1.2568 | g_loss: 1.1722
# Epoch[  196/  200] | d_loss: 1.2749 | g_loss: 1.1622
# Epoch[  197/  200] | d_loss: 1.2459 | g_loss: 1.3401
# Epoch[  197/  200] | d_loss: 1.2595 | g_loss: 1.0248
# Epoch[  197/  200] | d_loss: 1.3313 | g_loss: 0.9097
# Epoch[  198/  200] | d_loss: 1.1810 | g_loss: 1.3406
# Epoch[  198/  200] | d_loss: 1.1285 | g_loss: 1.1414
# Epoch[  198/  200] | d_loss: 1.3006 | g_loss: 1.3322
# Epoch[  199/  200] | d_loss: 1.2982 | g_loss: 0.8589
# Epoch[  199/  200] | d_loss: 1.2241 | g_loss: 1.0677
# Epoch[  199/  200] | d_loss: 1.3955 | g_loss: 0.7958
# Epoch[  200/  200] | d_loss: 1.3323 | g_loss: 1.0551
# Epoch[  200/  200] | d_loss: 1.1132 | g_loss: 1.0044
# Epoch[  200/  200] | d_loss: 1.3966 | g_loss: 1.0929
# số vòng lặp train của D:  187600

# %% [markdown]
# #Training loss
# Biểu đồ thể hiện giá trị hàm loss của G và D sau mỗi epoch
# ;

# %%
figure = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label = "Discriminator")
plt.plot(losses.T[1], label = "Generator")
plt.title("Training losses")
plt.legend()

# %% [markdown]
# #Ảnh Generator sinh ra trong training

# %%
def view_sample(epoch, samples):
  figure, axes = plt.subplots(figsize = (7, 7), nrows = 4, ncols = 4, sharey=True, sharex=True)
  for ax, img in zip(axes.flatten(), samples[epoch]):
    img = img.detach()
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    im = ax.imshow(img.reshape((28, 28)), cmap='Greys_r')

#lấy mẫu từ G trong quá trình training
with open('train_samples.pkl', 'rb') as f:
  samples = pkl.load(f)

# %%
#Ảnh sau epoch đầu
view_sample(0, samples)

# %%
#Ảnh sau epoch cuối
view_sample(-1, samples)

# %% [markdown]
# Ảnh sinh ra từ G trong quá trình training, mỗi 10 epoch

# %%
fig, axes = plt.subplots(figsize = (7, 12), nrows = 10, ncols = 5, sharex = True, sharey = True)
for sample, ax_row in zip(samples[::int(len(samples)/10)], axes):
  for img, ax in zip(sample[: : int(len(sample)/5)], ax_row):
    image = img.detach()
    ax.imshow(image.reshape((28, 28)), cmap = 'Greys_r')
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)

# %% [markdown]
# #Mẫu ảnh từ Generator

# %%
sample_size=16
rand_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
rand_z = torch.from_numpy(rand_z).float()

G.eval()

rand_images = G(rand_z)

view_sample(0, [rand_images])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
